# %% [markdown]
# # 1.	Problem Statement
# ```
#    Predict July payment status
#    Do customers pay the payment on time or defaulted?
# ```

# %% [markdown]
# # 2. Data Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import  pyplot as plt
data = pd.read_csv("/Users/manancy/Downloads/Nancy 2/工作/Carlo /尝试的业务/RisklabDataCompetition/1 Credit Card Debt Crisis/data for participants.csv")

# %% [markdown]
# ```
# Credit_Limit:      "200"-"40000"
# Sex:               “1” = Male, “2” = Female, other values = unknown
# Education:             “1” = Master's degree & Doctoral Degree, “2” =Bachelor’s Degree, “3” =High School’s Degree, “4”
#                         =Others, other value = unknown
# Marital_Status:         “1” = Married, “2” = Single, “3” = Others, other value  = unknown)
# Age:                    "14"-"100"
# Jan_Repay_Status~ Jul_Repay_Status:    “-n” = paid on time properly, “n” = payment delayed for n month already
#
# Previous_Payment_Prior_Jan
#  ~ Previous_Payment_Prior_Jun:         "-50000"-"50000"
#
# Jan_Statement ~ Jun_Statement:          "-50000"-"50000"
# July_Payment_Status:                    “0” = Paid on time, “1” = Defaulted on July Statement Balance
# ```

# %%
data
# Out:
#        Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 0            9600.0  1.0        3.0             3.0  32.0               6.0
# 1           14400.0  2.0        3.0             2.0  30.0              -2.0
# 2            8100.0  1.0        1.0             2.0  29.0              -1.0
# 3            2700.0  2.0        2.0             1.0  31.0               0.0
# 4           14500.0  2.0        2.0             1.0  37.0              -2.0
# ...             ...  ...        ...             ...   ...               ...
# 30597        1700.0  2.0        2.0             1.0  29.0               0.0
# 30598        4700.0  1.0        1.0             2.0  33.0               2.0
# 30599        6000.0  2.0        1.0             2.0  53.0               0.0
# 30600       14500.0  2.0        3.0             2.0  46.0              -2.0
# 30601        2500.0  2.0        2.0             1.0  51.0              -1.0
#
#        Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 0                           110.0          138.0               5.0
# 1                             0.0          132.0              -2.0
# 2                           133.0            7.0              -1.0
# 3                           104.0         2891.0               0.0
# 4                           309.0          403.0              -2.0
# ...                           ...            ...               ...
# 30597                        80.0         1598.0               0.0
# 30598                        80.0         2082.0               0.0
# 30599                       191.0         5418.0               0.0
# 30600                        28.0            0.0              -2.0
# 30601                        16.0           16.0              -1.0
#
#        Previous_Payment_Prior_Feb  ...  Apr_Repay_Status  \
# 0                          2847.0  ...               7.0
# 1                             0.0  ...              -2.0
# 2                          1700.0  ...              -1.0
# 3                           140.0  ...               0.0
# 4                            94.0  ...              -2.0
# ...                           ...  ...               ...
# 30597                        80.0  ...               0.0
# 30598                        80.0  ...               0.0
# 30599                       198.0  ...               0.0
# 30600                         0.0  ...              -2.0
# 30601                        16.0  ...              -1.0
#
#        Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 0                           331.0         1080.0              12.0
# 1                             0.0            0.0              -2.0
# 2                           751.0           -4.0              -1.0
# 3                            40.0         2842.0               0.0
# 4                           362.0          381.0              -2.0
# ...                           ...            ...               ...
# 30597                        56.0         1598.0               0.0
# 30598                       100.0         2194.0               0.0
# 30599                       165.0         5740.0               0.0
# 30600                        61.0            0.0              -2.0
# 30601                        22.0           16.0              -1.0
#
#        Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 0                           535.0         1671.0               3.0
# 1                            45.0            0.0              -2.0
# 2                           498.0          747.0              -1.0
# 3                            60.0         1187.0               0.0
# 4                             0.0          362.0              -2.0
# ...                           ...            ...               ...
# 30597                        52.0         1556.0               0.0
# 30598                       100.0         2258.0               0.0
# 30599                       201.0         5842.0               0.0
# 30600                         0.0           61.0              -2.0
# 30601                        16.0           22.0              -1.0
#
#        Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 0                          4800.0         6799.0                  1.0
# 1                           136.0           45.0                  0.0
# 2                           381.0          496.0                  0.0
# 3                            19.0         1153.0                  0.0
# 4                           116.0            0.0                  0.0
# ...                           ...            ...                  ...
# 30597                        80.0         1509.0                  0.0
# 30598                       100.0         2321.0                  1.0
# 30599                       140.0         5994.0                  1.0
# 30600                         0.0            0.0                  0.0
# 30601                        16.0           16.0                  1.0
#
# [30602 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30602 entries, 0 to 30601
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Credit_Limit                30602 non-null  float64
#  1   Sex                         30601 non-null  float64
#  2   Education                   30599 non-null  float64
#  3   Marital_Status              30598 non-null  float64
#  4   Age                         30595 non-null  float64
#  5   Jan_Repay_Status            30597 non-null  float64
#  6   Previous_Payment_Prior_Jan  30599 non-null  float64
#  7   Jan_Statement               30595 non-null  float64
#  8   Feb_Repay_Status            30600 non-null  float64
#  9   Previous_Payment_Prior_Feb  30597 non-null  float64
#  10  Feb_Statement               30595 non-null  float64
#  11  Mar_Repay_Status            30599 non-null  float64
#  12  Previous_Payment_Prior_Mar  30600 non-null  float64
#  13  Mar_Statement               30598 non-null  float64
#  14  Apr_Repay_Status            30598 non-null  float64
#  15  Previous_Payment_Prior_Apr  30599 non-null  float64
#  16  Apr_Statement               30599 non-null  float64
#  17  May_Repay_Status            30601 non-null  float64
#  18  Previous_Payment_Prior_May  30598 non-null  float64
#  19  May_Statement               30599 non-null  float64
#  20  Jun_Repay_Status            30600 non-null  float64
#  21  Previous_Payment_Prior_Jun  30600 non-null  float64
#  22  Jun_Statement               30597 non-null  float64
#  23  July_Payment_Status         30601 non-null  float64
# dtypes: float64(24)
# memory usage: 5.6 MB

# %%
# missing value：except for Credit_Limit

# %%
data.shape
# Out:
# (30602, 24)

# %%
data.describe().T
# Out:
#                               count         mean          std      min  \
# Credit_Limit                30602.0  6672.102712  5165.664158    200.0
# Sex                         30601.0     1.600667     0.510355      0.0
# Education                   30599.0     1.872349     0.816311      0.0
# Marital_Status              30598.0     1.560625     0.533208      0.0
# Age                         30595.0    35.835921    10.142700     14.0
# Jan_Repay_Status            30597.0     0.069615     1.396863     -2.0
# Previous_Payment_Prior_Jan  30599.0   243.085297   697.377685      0.0
# Jan_Statement               30595.0  2058.031084  2936.812290  -6623.0
# Feb_Repay_Status            30600.0    -0.043595     1.466934     -2.0
# Previous_Payment_Prior_Feb  30597.0   252.887473   941.932594      0.0
# Feb_Statement               30595.0  1976.916980  2838.897745  -2791.0
# Mar_Repay_Status            30599.0    -0.077715     1.469889     -2.0
# Previous_Payment_Prior_Mar  30600.0   226.045719   732.997242      0.0
# Mar_Statement               30598.0  1892.101118  2766.963253  -6291.0
# Apr_Repay_Status            30598.0    -0.123636     1.470158     -2.0
# Previous_Payment_Prior_Apr  30599.0   209.955619   662.602886      0.0
# Apr_Statement               30599.0  1741.370045  2566.962601  -6800.0
# May_Repay_Status            30601.0    -0.173393     1.430435     -2.0
# Previous_Payment_Prior_May  30598.0   208.100431   643.601986      0.0
# May_Statement               30599.0  1626.891434  2430.148971  -3253.0
# Jun_Repay_Status            30600.0    -0.197680     1.449626     -2.0
# Previous_Payment_Prior_Jun  30600.0   227.101667   745.095203      0.0
# Jun_Statement               30597.0  1573.701213  2385.559628 -13584.0
# July_Payment_Status         30601.0     0.225189     0.417948      0.0
#
#                                25%     50%      75%      max
# Credit_Limit                2100.0  5600.0  9500.00  40100.0
# Sex                            1.0     2.0     2.00      8.0
# Education                      1.0     2.0     2.00      6.0
# Marital_Status                 1.0     2.0     2.00      4.0
# Age                           28.0    34.0    42.00    102.0
# Jan_Repay_Status              -1.0     0.0     0.00     12.0
# Previous_Payment_Prior_Jan    40.0    87.0   205.00  34942.0
# Jan_Statement                147.0   914.0  2712.00  38580.0
# Feb_Repay_Status              -1.0     0.0     0.00     12.0
# Previous_Payment_Prior_Feb    36.0    82.0   200.00  67370.0
# Feb_Statement                125.0   867.0  2587.00  39357.0
# Mar_Repay_Status              -1.0     0.0     0.00     12.0
# Previous_Payment_Prior_Mar    16.0    76.0   194.00  35842.0
# Mar_Statement                114.0   814.5  2443.75  66564.0
# Apr_Repay_Status              -1.0     0.0     0.00     12.0
# Previous_Payment_Prior_Apr    12.0    61.0   171.00  24840.0
# Apr_Statement                 97.0   770.0  2212.00  35663.0
# May_Repay_Status              -1.0     0.0     0.00     12.0
# Previous_Payment_Prior_May    12.0    62.0   170.75  17061.0
# May_Statement                 75.0   734.0  2029.00  37087.0
# Jun_Repay_Status              -1.0     0.0     0.00     12.0
# Previous_Payment_Prior_Jun     7.0    60.0   168.00  21147.0
# Jun_Statement                 53.0   694.0  1992.00  38467.0
# July_Payment_Status            0.0     0.0     0.00      2.0

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# ###  3.1 Remove duplicate values

# %%
data.drop_duplicates(keep="first",inplace=True)

# %%
data.index = range(data.shape[0])  # organize 
data
# Out:
#        Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 0            9600.0  1.0        3.0             3.0  32.0               6.0
# 1           14400.0  2.0        3.0             2.0  30.0              -2.0
# 2            8100.0  1.0        1.0             2.0  29.0              -1.0
# 3            2700.0  2.0        2.0             1.0  31.0               0.0
# 4           14500.0  2.0        2.0             1.0  37.0              -2.0
# ...             ...  ...        ...             ...   ...               ...
# 30580        1700.0  2.0        2.0             1.0  29.0               0.0
# 30581        4700.0  1.0        1.0             2.0  33.0               2.0
# 30582        6000.0  2.0        1.0             2.0  53.0               0.0
# 30583       14500.0  2.0        3.0             2.0  46.0              -2.0
# 30584        2500.0  2.0        2.0             1.0  51.0              -1.0
#
#        Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 0                           110.0          138.0               5.0
# 1                             0.0          132.0              -2.0
# 2                           133.0            7.0              -1.0
# 3                           104.0         2891.0               0.0
# 4                           309.0          403.0              -2.0
# ...                           ...            ...               ...
# 30580                        80.0         1598.0               0.0
# 30581                        80.0         2082.0               0.0
# 30582                       191.0         5418.0               0.0
# 30583                        28.0            0.0              -2.0
# 30584                        16.0           16.0              -1.0
#
#        Previous_Payment_Prior_Feb  ...  Apr_Repay_Status  \
# 0                          2847.0  ...               7.0
# 1                             0.0  ...              -2.0
# 2                          1700.0  ...              -1.0
# 3                           140.0  ...               0.0
# 4                            94.0  ...              -2.0
# ...                           ...  ...               ...
# 30580                        80.0  ...               0.0
# 30581                        80.0  ...               0.0
# 30582                       198.0  ...               0.0
# 30583                         0.0  ...              -2.0
# 30584                        16.0  ...              -1.0
#
#        Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 0                           331.0         1080.0              12.0
# 1                             0.0            0.0              -2.0
# 2                           751.0           -4.0              -1.0
# 3                            40.0         2842.0               0.0
# 4                           362.0          381.0              -2.0
# ...                           ...            ...               ...
# 30580                        56.0         1598.0               0.0
# 30581                       100.0         2194.0               0.0
# 30582                       165.0         5740.0               0.0
# 30583                        61.0            0.0              -2.0
# 30584                        22.0           16.0              -1.0
#
#        Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 0                           535.0         1671.0               3.0
# 1                            45.0            0.0              -2.0
# 2                           498.0          747.0              -1.0
# 3                            60.0         1187.0               0.0
# 4                             0.0          362.0              -2.0
# ...                           ...            ...               ...
# 30580                        52.0         1556.0               0.0
# 30581                       100.0         2258.0               0.0
# 30582                       201.0         5842.0               0.0
# 30583                         0.0           61.0              -2.0
# 30584                        16.0           22.0              -1.0
#
#        Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 0                          4800.0         6799.0                  1.0
# 1                           136.0           45.0                  0.0
# 2                           381.0          496.0                  0.0
# 3                            19.0         1153.0                  0.0
# 4                           116.0            0.0                  0.0
# ...                           ...            ...                  ...
# 30580                        80.0         1509.0                  0.0
# 30581                       100.0         2321.0                  1.0
# 30582                       140.0         5994.0                  1.0
# 30583                         0.0            0.0                  0.0
# 30584                        16.0           16.0                  1.0
#
# [30585 rows x 24 columns]

# %% [markdown]
# ### 3.2 Missing Values

# %%
data.isnull().sum()
# data.isnull().sum()/data.shape[0]
# Out:
# Credit_Limit                  0
# Sex                           1
# Education                     3
# Marital_Status                4
# Age                           7
# Jan_Repay_Status              5
# Previous_Payment_Prior_Jan    3
# Jan_Statement                 7
# Feb_Repay_Status              2
# Previous_Payment_Prior_Feb    5
# Feb_Statement                 7
# Mar_Repay_Status              3
# Previous_Payment_Prior_Mar    2
# Mar_Statement                 4
# Apr_Repay_Status              4
# Previous_Payment_Prior_Apr    3
# Apr_Statement                 3
# May_Repay_Status              1
# Previous_Payment_Prior_May    4
# May_Statement                 3
# Jun_Repay_Status              2
# Previous_Payment_Prior_Jun    2
# Jun_Statement                 5
# July_Payment_Status           1
# dtype: int64

# %% [markdown]
# #### 3.2.1 Jan to Jun Repay Staus, Previous Payment Prior Jan to Jun, and Jan to Jun Statement Missing Values
#         Using mean to fill NaN

# %%
# numbers use mean to fill NaN
Missing_values =["Jan_Repay_Status","Feb_Repay_Status","Mar_Repay_Status","Apr_Repay_Status","May_Repay_Status","Jun_Repay_Status",
                "Previous_Payment_Prior_Jan","Previous_Payment_Prior_Feb","Previous_Payment_Prior_Mar","Previous_Payment_Prior_Apr","Previous_Payment_Prior_May","Previous_Payment_Prior_Jun",
                "Jan_Statement","Feb_Statement","Mar_Statement","Apr_Statement","May_Statement","Jun_Statement"]
for i in Missing_values:
    data[i].fillna(int(data[i].mean()), inplace=True)

# %% [markdown]
# #### 3.2.2 Sex Missing Values
#     Using mode to fill NaN
#     Sex: “1” = Male, “2” = Female, other values = unknown.
#     Keep “1” male and “2” female.

# %%
data["Sex"].value_counts()
# Out:
# 2.0    18298
# 1.0    12103
# 0.0      113
# 3.0       46
# 4.0       14
# 5.0        3
# 7.0        3
# 6.0        3
# 8.0        1
# Name: Sex, dtype: int64

# %%
data["Sex"].mode()
# Out:
# 0    2.0
# dtype: float64

# %%
data["Sex"]=data["Sex"].replace([0,3,4,5,6,7,8],2)
data["Sex"].fillna(int(data["Sex"].mode()), inplace=True) #1 missing

# %%
data["Sex"].value_counts()
# Out:
# 2.0    18482
# 1.0    12103
# Name: Sex, dtype: int64

# %% [markdown]
# #### 3.2.3 Education Missing Value
#     Using mode to fill NaN
#     Education:“1” = Master's degree & Doctoral Degree, “2” =Bachelor’s Degree, “3” =High School’s Degree, “4”

# %%
data["Education"].value_counts()
# Out:
# 2.0    14154
# 1.0    10704
# 3.0     5059
# 5.0      369
# 4.0      231
# 6.0       51
# 0.0       14
# Name: Education, dtype: int64

# %%
data["Education"].mode()
# Out:
# 0    2.0
# dtype: float64

# %%
data["Education"]=data["Education"].replace([0,5,6],2)
data["Education"].fillna(int(data["Education"].mode()), inplace=True) #3 missing
data["Education"].value_counts()
# Out:
# 2.0    14591
# 1.0    10704
# 3.0     5059
# 4.0      231
# Name: Education, dtype: int64

# %% [markdown]
# #### 3.2.4 Marital Status Missing Value
#     Marital_Status: “1” = Married, “2” = Single, “3” = Others, other value  = unknown)
#     Using mode to fill NaN
#     Keep "1" & "2"

# %%
data["Marital_Status"].value_counts()
# Out:
# 2.0    16169
# 1.0    13847
# 3.0      503
# 0.0       54
# 4.0        8
# Name: Marital_Status, dtype: int64

# %%
data["Marital_Status"].mode()
# Out:
# 0    2.0
# dtype: float64

# %%
data["Marital_Status"]=data["Marital_Status"].replace([0,3,4],2)
data["Marital_Status"].fillna(int(data["Marital_Status"].mode()), inplace=True) #4 missing
data["Marital_Status"].value_counts()
# Out:
# 2.0    16738
# 1.0    13847
# Name: Marital_Status, dtype: int64

# %% [markdown]
# #### 3.2.5 Age Missing Values
#     Using mode to fill NaN
#     Age:"14"-"100"
#     Keep the range of 14 - 100 years old

# %%
data["Age"].value_counts()
# Out:
# 29.0     1406
# 27.0     1403
# 28.0     1393
# 31.0     1373
# 30.0     1360
#          ...
# 89.0        3
# 100.0       2
# 102.0       2
# 101.0       1
# 14.0        1
# Name: Age, Length: 88, dtype: int64

# %%
data[data["Age"]>100]
# Out:
#        Credit_Limit  Sex  Education  Marital_Status    Age  Jan_Repay_Status  \
# 476          9500.0  1.0        2.0             2.0  102.0               3.0
# 5740         2100.0  2.0        4.0             2.0  101.0               8.0
# 12201         600.0  1.0        4.0             1.0  102.0               7.0
#
#        Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 476                        2423.0         3074.0               6.0
# 5740                        410.0         1832.0               6.0
# 12201                        56.0           81.0              10.0
#
#        Previous_Payment_Prior_Feb  ...  Apr_Repay_Status  \
# 476                        2037.0  ...               2.0
# 5740                       1869.0  ...               3.0
# 12201                        28.0  ...               5.0
#
#        Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 476                        1131.0         3267.0               5.0
# 5740                       1010.0         1921.0               9.0
# 12201                       148.0          342.0               5.0
#
#        Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 476                        2705.0         8335.0               7.0
# 5740                        928.0         2017.0               0.0
# 12201                        56.0          147.0               7.0
#
#        Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 476                        3998.0         7278.0                  1.0
# 5740                        522.0         1197.0                  0.0
# 12201                       202.0          457.0                  1.0
#
# [3 rows x 24 columns]

# %%
data[data["Age"]<14]
# Out:
# Empty DataFrame
# Columns: [Credit_Limit, Sex, Education, Marital_Status, Age, Jan_Repay_Status, Previous_Payment_Prior_Jan, Jan_Statement, Feb_Repay_Status, Previous_Payment_Prior_Feb, Feb_Statement, Mar_Repay_Status, Previous_Payment_Prior_Mar, Mar_Statement, Apr_Repay_Status, Previous_Payment_Prior_Apr, Apr_Statement, May_Repay_Status, Previous_Payment_Prior_May, May_Statement, Jun_Repay_Status, Previous_Payment_Prior_Jun, Jun_Statement, July_Payment_Status]
# Index: []
#
# [0 rows x 24 columns]

# %%
data["Age"].mode()
# Out:
# 0    29.0
# dtype: float64

# %%
data["Age"]=data["Age"].replace([101,102],29)  # replace by nearest age in the range
data["Age"].fillna(int(data["Age"].mode()), inplace=True)  # 7 missing 
data["Age"].unique()
# Out:
# array([ 32.,  30.,  29.,  31.,  37.,  18.,  33.,  38.,  66.,  28.,  39.,
#         35.,  23.,  49.,  26.,  57.,  41.,  52.,  60.,  47.,  24.,  40.,
#         44.,  36.,  48.,  43.,  72.,  34.,  27.,  67.,  25.,  42.,  51.,
#         58.,  56.,  21.,  64.,  22.,  20.,  45.,  70.,  55.,  50.,  54.,
#         53.,  46.,  19.,  59.,  98.,  96.,  63.,  80.,  68.,  84.,  62.,
#         88.,  65.,  95.,  17.,  61.,  97.,  83.,  90.,  85.,  74.,  73.,
#         87.,  81.,  69.,  93.,  15.,  77.,  91.,  94.,  76.,  71.,  82.,
#         75.,  78.,  89.,  16.,  79.,  92., 100.,  99.,  14.])

# %%
data[data["Age"]>100]
# Out:
# Empty DataFrame
# Columns: [Credit_Limit, Sex, Education, Marital_Status, Age, Jan_Repay_Status, Previous_Payment_Prior_Jan, Jan_Statement, Feb_Repay_Status, Previous_Payment_Prior_Feb, Feb_Statement, Mar_Repay_Status, Previous_Payment_Prior_Mar, Mar_Statement, Apr_Repay_Status, Previous_Payment_Prior_Apr, Apr_Statement, May_Repay_Status, Previous_Payment_Prior_May, May_Statement, Jun_Repay_Status, Previous_Payment_Prior_Jun, Jun_Statement, July_Payment_Status]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# #### 3.2.6 July_Payment_Status Missing Values
#     July_Payment_Status: “0” = Paid on time, “1” = Defaulted on July Statement Balance
#     just 1 missing and delete it from the data

# %%
data["July_Payment_Status"].unique()
# Out:
# array([ 1.,  0.,  2., nan])

# %%
data["July_Payment_Status"].value_counts()
# Out:
# 0.0    23701
# 1.0     6880
# 2.0        3
# Name: July_Payment_Status, dtype: int64

# %%
data.dropna(axis=0,subset = ["July_Payment_Status"],inplace=True)
data[data["July_Payment_Status"]==2]
# Out:
#        Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 3356         1300.0  2.0        1.0             1.0  51.0              -1.0
# 6446         8100.0  2.0        3.0             1.0  84.0               4.0
# 26963        6600.0  2.0        4.0             1.0  70.0               0.0
#
#        Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 3356                         58.0           97.0               9.0
# 6446                        679.0         3131.0              10.0
# 26963                      3466.0         5299.0               7.0
#
#        Previous_Payment_Prior_Feb  ...  Apr_Repay_Status  \
# 3356                        134.0  ...              12.0
# 6446                        214.0  ...               3.0
# 26963                       322.0  ...              12.0
#
#        Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 3356                        379.0          440.0               1.0
# 6446                        210.0          113.0               8.0
# 26963                       983.0         1274.0               6.0
#
#        Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 3356                         72.0         1627.0               5.0
# 6446                         64.0          117.0               3.0
# 26963                      1459.0         2321.0               9.0
#
#        Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 3356                        352.0          389.0                  2.0
# 6446                       1576.0         7240.0                  2.0
# 26963                      4828.0         5323.0                  2.0
#
# [3 rows x 24 columns]

# %%
data.drop(index=data[data.July_Payment_Status==2].index, inplace=True)

# %%
data.isnull().sum()
# Out:
# Credit_Limit                  0
# Sex                           0
# Education                     0
# Marital_Status                0
# Age                           0
# Jan_Repay_Status              0
# Previous_Payment_Prior_Jan    0
# Jan_Statement                 0
# Feb_Repay_Status              0
# Previous_Payment_Prior_Feb    0
# Feb_Statement                 0
# Mar_Repay_Status              0
# Previous_Payment_Prior_Mar    0
# Mar_Statement                 0
# Apr_Repay_Status              0
# Previous_Payment_Prior_Apr    0
# Apr_Statement                 0
# May_Repay_Status              0
# Previous_Payment_Prior_May    0
# May_Statement                 0
# Jun_Repay_Status              0
# Previous_Payment_Prior_Jun    0
# Jun_Statement                 0
# July_Payment_Status           0
# dtype: int64

# %%
data
# Out:
#        Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 0            9600.0  1.0        3.0             2.0  32.0               6.0
# 1           14400.0  2.0        3.0             2.0  30.0              -2.0
# 2            8100.0  1.0        1.0             2.0  29.0              -1.0
# 3            2700.0  2.0        2.0             1.0  31.0               0.0
# 4           14500.0  2.0        2.0             1.0  37.0              -2.0
# ...             ...  ...        ...             ...   ...               ...
# 30580        1700.0  2.0        2.0             1.0  29.0               0.0
# 30581        4700.0  1.0        1.0             2.0  33.0               2.0
# 30582        6000.0  2.0        1.0             2.0  53.0               0.0
# 30583       14500.0  2.0        3.0             2.0  46.0              -2.0
# 30584        2500.0  2.0        2.0             1.0  51.0              -1.0
#
#        Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 0                           110.0          138.0               5.0
# 1                             0.0          132.0              -2.0
# 2                           133.0            7.0              -1.0
# 3                           104.0         2891.0               0.0
# 4                           309.0          403.0              -2.0
# ...                           ...            ...               ...
# 30580                        80.0         1598.0               0.0
# 30581                        80.0         2082.0               0.0
# 30582                       191.0         5418.0               0.0
# 30583                        28.0            0.0              -2.0
# 30584                        16.0           16.0              -1.0
#
#        Previous_Payment_Prior_Feb  ...  Apr_Repay_Status  \
# 0                          2847.0  ...               7.0
# 1                             0.0  ...              -2.0
# 2                          1700.0  ...              -1.0
# 3                           140.0  ...               0.0
# 4                            94.0  ...              -2.0
# ...                           ...  ...               ...
# 30580                        80.0  ...               0.0
# 30581                        80.0  ...               0.0
# 30582                       198.0  ...               0.0
# 30583                         0.0  ...              -2.0
# 30584                        16.0  ...              -1.0
#
#        Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 0                           331.0         1080.0              12.0
# 1                             0.0            0.0              -2.0
# 2                           751.0           -4.0              -1.0
# 3                            40.0         2842.0               0.0
# 4                           362.0          381.0              -2.0
# ...                           ...            ...               ...
# 30580                        56.0         1598.0               0.0
# 30581                       100.0         2194.0               0.0
# 30582                       165.0         5740.0               0.0
# 30583                        61.0            0.0              -2.0
# 30584                        22.0           16.0              -1.0
#
#        Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 0                           535.0         1671.0               3.0
# 1                            45.0            0.0              -2.0
# 2                           498.0          747.0              -1.0
# 3                            60.0         1187.0               0.0
# 4                             0.0          362.0              -2.0
# ...                           ...            ...               ...
# 30580                        52.0         1556.0               0.0
# 30581                       100.0         2258.0               0.0
# 30582                       201.0         5842.0               0.0
# 30583                         0.0           61.0              -2.0
# 30584                        16.0           22.0              -1.0
#
#        Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 0                          4800.0         6799.0                  1.0
# 1                           136.0           45.0                  0.0
# 2                           381.0          496.0                  0.0
# 3                            19.0         1153.0                  0.0
# 4                           116.0            0.0                  0.0
# ...                           ...            ...                  ...
# 30580                        80.0         1509.0                  0.0
# 30581                       100.0         2321.0                  1.0
# 30582                       140.0         5994.0                  1.0
# 30583                         0.0            0.0                  0.0
# 30584                        16.0           16.0                  1.0
#
# [30581 rows x 24 columns]

# %% [markdown]
# # 4. Filter unwanted outliers
#     Using IQR method to get the outliners and delete them

# %%
#data.describe().T

# %%
features = data.columns.to_list()
#features
type(features)
len(features)
# Out:
# 24

# %%
import warnings
warnings.filterwarnings('ignore')
print("Lower tail:","Lt")
print("Upper tail:","Ut")
i = 1
Ls=[]
plt.figure()
fig, ax = plt.subplots(8, 3,figsize=(35, 55))
for I in features:
    df=data[I]
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    A=[I,Lower_tail,Upper_tail]
    Ls.append(A)
    plt.subplot(8, 3,i)
    sns.boxplot(df)
    plt.title(A,fontsize=25)
    plt.xticks(fontsize=20)
    i += 1
plt.show()
# Out:
# Lower tail: Lt
# Upper tail: Ut

# %%
# import warnings
# warnings.filterwarnings('ignore')
# Ls=[]
# for I in features:
#     df=data[I]
#     q1 = df.quantile(0.25)
#     q3 = df.quantile(0.75)
#     iqr = q3-q1
#     Lower_tail = q1 - 1.5 * iqr
#     Upper_tail = q3 + 1.5 * iqr
#     A=[I,Lower_tail,Upper_tail]
#     Ls.append(A)
#     print(I,Lower_tail,Upper_tail)
#     plt.figure(figsize=(5, 2))
#     plt.title("Box Plot")
#     sns.boxplot(df)
#     plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30581 entries, 0 to 30584
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Credit_Limit                30581 non-null  float64
#  1   Sex                         30581 non-null  float64
#  2   Education                   30581 non-null  float64
#  3   Marital_Status              30581 non-null  float64
#  4   Age                         30581 non-null  float64
#  5   Jan_Repay_Status            30581 non-null  float64
#  6   Previous_Payment_Prior_Jan  30581 non-null  float64
#  7   Jan_Statement               30581 non-null  float64
#  8   Feb_Repay_Status            30581 non-null  float64
#  9   Previous_Payment_Prior_Feb  30581 non-null  float64
#  10  Feb_Statement               30581 non-null  float64
#  11  Mar_Repay_Status            30581 non-null  float64
#  12  Previous_Payment_Prior_Mar  30581 non-null  float64
#  13  Mar_Statement               30581 non-null  float64
#  14  Apr_Repay_Status            30581 non-null  float64
#  15  Previous_Payment_Prior_Apr  30581 non-null  float64
#  16  Apr_Statement               30581 non-null  float64
#  17  May_Repay_Status            30581 non-null  float64
#  18  Previous_Payment_Prior_May  30581 non-null  float64
#  19  May_Statement               30581 non-null  float64
#  20  Jun_Repay_Status            30581 non-null  float64
#  21  Previous_Payment_Prior_Jun  30581 non-null  float64
#  22  Jun_Statement               30581 non-null  float64
#  23  July_Payment_Status         30581 non-null  float64
# dtypes: float64(24)
# memory usage: 5.8 MB

# %%
Ls
# Out:
# [['Credit_Limit', -9000.0, 20600.0],
#  ['Sex', -0.5, 3.5],
#  ['Education', -0.5, 3.5],
#  ['Marital_Status', -0.5, 3.5],
#  ['Age', 7.0, 63.0],
#  ['Jan_Repay_Status', -2.5, 1.5],
#  ['Previous_Payment_Prior_Jan', -207.5, 452.5],
#  ['Jan_Statement', -3698.0, 6558.0],
#  ['Feb_Repay_Status', -2.5, 1.5],
#  ['Previous_Payment_Prior_Feb', -210.0, 446.0],
#  ['Feb_Statement', -3565.5, 6278.5],
#  ['Mar_Repay_Status', -2.5, 1.5],
#  ['Previous_Payment_Prior_Mar', -251.0, 461.0],
#  ['Mar_Statement', -3379.5, 5936.5],
#  ['Apr_Repay_Status', -2.5, 1.5],
#  ['Previous_Payment_Prior_Apr', -228.0, 412.0],
#  ['Apr_Statement', -3078.5, 5389.5],
#  ['May_Repay_Status', -2.5, 1.5],
#  ['Previous_Payment_Prior_May', -226.5, 409.5],
#  ['May_Statement', -2856.0, 4960.0],
#  ['Jun_Repay_Status', -2.5, 1.5],
#  ['Previous_Payment_Prior_Jun', -234.5, 409.5],
#  ['Jun_Statement', -2855.5, 4900.5],
#  ['July_Payment_Status', 0.0, 0.0]]

# %%
Name=[]
lt= []
ut= []
for i in Ls:
    a=i[0]
    Name.append(a)
    b=i[1]
    lt.append(b)
    c=i[2]
    ut.append(c)
    data.drop(index=data.loc[(data[a] < b) & (data[a] < c)].index,inplace=True)

# %%
data.index = range(data.shape[0])  # organize row numbers
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30570 entries, 0 to 30569
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Credit_Limit                30570 non-null  float64
#  1   Sex                         30570 non-null  float64
#  2   Education                   30570 non-null  float64
#  3   Marital_Status              30570 non-null  float64
#  4   Age                         30570 non-null  float64
#  5   Jan_Repay_Status            30570 non-null  float64
#  6   Previous_Payment_Prior_Jan  30570 non-null  float64
#  7   Jan_Statement               30570 non-null  float64
#  8   Feb_Repay_Status            30570 non-null  float64
#  9   Previous_Payment_Prior_Feb  30570 non-null  float64
#  10  Feb_Statement               30570 non-null  float64
#  11  Mar_Repay_Status            30570 non-null  float64
#  12  Previous_Payment_Prior_Mar  30570 non-null  float64
#  13  Mar_Statement               30570 non-null  float64
#  14  Apr_Repay_Status            30570 non-null  float64
#  15  Previous_Payment_Prior_Apr  30570 non-null  float64
#  16  Apr_Statement               30570 non-null  float64
#  17  May_Repay_Status            30570 non-null  float64
#  18  Previous_Payment_Prior_May  30570 non-null  float64
#  19  May_Statement               30570 non-null  float64
#  20  Jun_Repay_Status            30570 non-null  float64
#  21  Previous_Payment_Prior_Jun  30570 non-null  float64
#  22  Jun_Statement               30570 non-null  float64
#  23  July_Payment_Status         30570 non-null  float64
# dtypes: float64(24)
# memory usage: 5.6 MB

# %%
#data
data.to_csv("/Users/manancy/Downloads/Nancy 2/工作/Carlo /尝试的业务/RisklabDataCompetition/1 Credit Card Debt Crisis/2nd/OverSample/Cleaned data-Nancy(before sub-sample).csv")

# %% [markdown]
# # 5. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 5.1 Does the data balance?

# %%
# imbalance 
# 30570 sample, 6878 defalted(1) , 23692(0) 
sns.countplot('July_Payment_Status', data=data)
plt.title('Class Distributions \n (0: Paid on time || 1: Defaulted)', fontsize=14)
print("Jul defaulted numbers:", data["July_Payment_Status"].sum())
# Out:
# Jul defaulted numbers: 6878.0

# %%
print('July payment paid on time', round(data['July_Payment_Status'].value_counts()[0]/len(data) * 100,2), '% of the dataset')
print('July payment defaulted', round(data['July_Payment_Status'].value_counts()[1]/len(data) * 100,2), '% of the dataset')
# Out:
# July payment paid on time 77.5 % of the dataset
# July payment defaulted 22.5 % of the dataset

# %% [markdown]
# ### 5.2 Create a new sub-sample
#         concat the 6878 defaulted

# %% [markdown]
# #### 5.2.1 Splitting the Data (Original)

# %%
#Original data
X=data.drop("July_Payment_Status",axis=1)
y=data["July_Payment_Status"]
len(y)
# Out:
# 30570

# %% [markdown]
# #### 5.2.2 Random Over-Sampling

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)  
X_smote, y_smote = sm.fit_resample(X, y)
#X_smote

# %%
new_data= pd.concat([X_smote,y_smote], axis=1)
#new_data
len(new_data)   # 30570= 47384/2+6878    # 47384/2=23692(0)
# Out:
# 47384

# %%
print('Distribution of the July_Payment_Status in the subsample dataset')
print(new_data['July_Payment_Status'].value_counts()/len(new_data))

sns.countplot('July_Payment_Status', data=new_data)
plt.title('Equally Distributed July_Payment_Status', fontsize=14)
plt.show()
# Out:
# Distribution of the July_Payment_Status in the subsample dataset
# 1.0    0.5
# 0.0    0.5
# Name: July_Payment_Status, dtype: float64

# %%
new_data.index = range(new_data.shape[0])
#new_data

# %%
new_data.to_csv("/Users/manancy/Downloads/Nancy 2/工作/Carlo /尝试的业务/RisklabDataCompetition/1 Credit Card Debt Crisis/2nd/OverSample/Cleaned Sub-oversample-Nancy.csv")

# %% [markdown]
# ### 5.3 Correlation Matrices

# %%
new_data.head()
# Out:
#    Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 0        9600.0  1.0        3.0             2.0  32.0               6.0
# 1       14400.0  2.0        3.0             2.0  30.0              -2.0
# 2        8100.0  1.0        1.0             2.0  29.0              -1.0
# 3        2700.0  2.0        2.0             1.0  31.0               0.0
# 4       14500.0  2.0        2.0             1.0  37.0              -2.0
#
#    Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 0                       110.0          138.0               5.0
# 1                         0.0          132.0              -2.0
# 2                       133.0            7.0              -1.0
# 3                       104.0         2891.0               0.0
# 4                       309.0          403.0              -2.0
#
#    Previous_Payment_Prior_Feb  ...  Apr_Repay_Status  \
# 0                      2847.0  ...               7.0
# 1                         0.0  ...              -2.0
# 2                      1700.0  ...              -1.0
# 3                       140.0  ...               0.0
# 4                        94.0  ...              -2.0
#
#    Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 0                       331.0         1080.0              12.0
# 1                         0.0            0.0              -2.0
# 2                       751.0           -4.0              -1.0
# 3                        40.0         2842.0               0.0
# 4                       362.0          381.0              -2.0
#
#    Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 0                       535.0         1671.0               3.0
# 1                        45.0            0.0              -2.0
# 2                       498.0          747.0              -1.0
# 3                        60.0         1187.0               0.0
# 4                         0.0          362.0              -2.0
#
#    Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 0                      4800.0         6799.0                  1.0
# 1                       136.0           45.0                  0.0
# 2                       381.0          496.0                  0.0
# 3                        19.0         1153.0                  0.0
# 4                       116.0            0.0                  0.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ```
# Negative Correlation: Jan~Jun_Repay_Status
# Positive Correlation: Other then Repay_Status
# ```

# %%
# Original Data
data1=data.copy()
Repay_Status_sum = data1[["Jan_Repay_Status","Feb_Repay_Status","Mar_Repay_Status","Apr_Repay_Status","May_Repay_Status","Jun_Repay_Status"]]
data1['Repay_Status_sum'] = Repay_Status_sum.apply(lambda x: x.sum(), axis=1)

Previous_Payment_Prior_sum=data1[["Previous_Payment_Prior_Jan","Previous_Payment_Prior_Feb","Previous_Payment_Prior_Mar","Previous_Payment_Prior_Apr","Previous_Payment_Prior_May","Previous_Payment_Prior_Jun"]]
data1["Previous_Payment_Prior_sum"]=Previous_Payment_Prior_sum.apply(lambda x: x.sum(), axis=1)

Statement_sum=data1[["Jan_Statement","Feb_Statement","Mar_Statement","Apr_Statement","May_Statement","Jun_Statement"]]
data1["Statement_sum"]=Statement_sum.apply(lambda x: x.sum(), axis=1)
data1.head()
# Out:
#    Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 0        9600.0  1.0        3.0             2.0  32.0               6.0
# 1       14400.0  2.0        3.0             2.0  30.0              -2.0
# 2        8100.0  1.0        1.0             2.0  29.0              -1.0
# 3        2700.0  2.0        2.0             1.0  31.0               0.0
# 4       14500.0  2.0        2.0             1.0  37.0              -2.0
#
#    Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 0                       110.0          138.0               5.0
# 1                         0.0          132.0              -2.0
# 2                       133.0            7.0              -1.0
# 3                       104.0         2891.0               0.0
# 4                       309.0          403.0              -2.0
#
#    Previous_Payment_Prior_Feb  ...  May_Repay_Status  \
# 0                      2847.0  ...              12.0
# 1                         0.0  ...              -2.0
# 2                      1700.0  ...              -1.0
# 3                       140.0  ...               0.0
# 4                        94.0  ...              -2.0
#
#    Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 0                       535.0         1671.0               3.0
# 1                        45.0            0.0              -2.0
# 2                       498.0          747.0              -1.0
# 3                        60.0         1187.0               0.0
# 4                         0.0          362.0              -2.0
#
#    Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status  \
# 0                      4800.0         6799.0                  1.0
# 1                       136.0           45.0                  0.0
# 2                       381.0          496.0                  0.0
# 3                        19.0         1153.0                  0.0
# 4                       116.0            0.0                  0.0
#
#    Repay_Status_sum  Previous_Payment_Prior_sum  Statement_sum
# 0              44.0                     10315.0        16878.0
# 1             -12.0                       181.0          177.0
# 2              -6.0                      3463.0         2919.0
# 3               0.0                       483.0        13835.0
# 4             -12.0                      1262.0         1549.0
#
# [5 rows x 27 columns]

# %%
data2= data1[["Credit_Limit","Sex","Education","Marital_Status","Age",
            "Repay_Status_sum","Previous_Payment_Prior_sum","Statement_sum","July_Payment_Status"]]
data2.head()
# Out:
#    Credit_Limit  Sex  Education  Marital_Status   Age  Repay_Status_sum  \
# 0        9600.0  1.0        3.0             2.0  32.0              44.0
# 1       14400.0  2.0        3.0             2.0  30.0             -12.0
# 2        8100.0  1.0        1.0             2.0  29.0              -6.0
# 3        2700.0  2.0        2.0             1.0  31.0               0.0
# 4       14500.0  2.0        2.0             1.0  37.0             -12.0
#
#    Previous_Payment_Prior_sum  Statement_sum  July_Payment_Status
# 0                     10315.0        16878.0                  1.0
# 1                       181.0          177.0                  0.0
# 2                      3463.0         2919.0                  0.0
# 3                       483.0        13835.0                  0.0
# 4                      1262.0         1549.0                  0.0

# %%
# Sub-Data
new_data1=new_data.copy()
Repay_Status_sum = new_data1[["Jan_Repay_Status","Feb_Repay_Status","Mar_Repay_Status","Apr_Repay_Status","May_Repay_Status","Jun_Repay_Status"]]
new_data1['Repay_Status_sum'] = Repay_Status_sum.apply(lambda x: x.sum(), axis=1)

Previous_Payment_Prior_sum=new_data1[["Previous_Payment_Prior_Jan","Previous_Payment_Prior_Feb","Previous_Payment_Prior_Mar","Previous_Payment_Prior_Apr","Previous_Payment_Prior_May","Previous_Payment_Prior_Jun"]]
new_data1["Previous_Payment_Prior_sum"]=Previous_Payment_Prior_sum.apply(lambda x: x.sum(), axis=1)

Statement_sum=new_data1[["Jan_Statement","Feb_Statement","Mar_Statement","Apr_Statement","May_Statement","Jun_Statement"]]
new_data1["Statement_sum"]=Statement_sum.apply(lambda x: x.sum(), axis=1)
data.head()
# Out:
#    Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 0        9600.0  1.0        3.0             2.0  32.0               6.0
# 1       14400.0  2.0        3.0             2.0  30.0              -2.0
# 2        8100.0  1.0        1.0             2.0  29.0              -1.0
# 3        2700.0  2.0        2.0             1.0  31.0               0.0
# 4       14500.0  2.0        2.0             1.0  37.0              -2.0
#
#    Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 0                       110.0          138.0               5.0
# 1                         0.0          132.0              -2.0
# 2                       133.0            7.0              -1.0
# 3                       104.0         2891.0               0.0
# 4                       309.0          403.0              -2.0
#
#    Previous_Payment_Prior_Feb  ...  Apr_Repay_Status  \
# 0                      2847.0  ...               7.0
# 1                         0.0  ...              -2.0
# 2                      1700.0  ...              -1.0
# 3                       140.0  ...               0.0
# 4                        94.0  ...              -2.0
#
#    Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 0                       331.0         1080.0              12.0
# 1                         0.0            0.0              -2.0
# 2                       751.0           -4.0              -1.0
# 3                        40.0         2842.0               0.0
# 4                       362.0          381.0              -2.0
#
#    Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 0                       535.0         1671.0               3.0
# 1                        45.0            0.0              -2.0
# 2                       498.0          747.0              -1.0
# 3                        60.0         1187.0               0.0
# 4                         0.0          362.0              -2.0
#
#    Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 0                      4800.0         6799.0                  1.0
# 1                       136.0           45.0                  0.0
# 2                       381.0          496.0                  0.0
# 3                        19.0         1153.0                  0.0
# 4                       116.0            0.0                  0.0
#
# [5 rows x 24 columns]

# %%
new_data2= new_data1[["Credit_Limit","Sex","Education","Marital_Status","Age",
            "Repay_Status_sum","Previous_Payment_Prior_sum","Statement_sum","July_Payment_Status"]]
new_data2.head()
# Out:
#    Credit_Limit  Sex  Education  Marital_Status   Age  Repay_Status_sum  \
# 0        9600.0  1.0        3.0             2.0  32.0              44.0
# 1       14400.0  2.0        3.0             2.0  30.0             -12.0
# 2        8100.0  1.0        1.0             2.0  29.0              -6.0
# 3        2700.0  2.0        2.0             1.0  31.0               0.0
# 4       14500.0  2.0        2.0             1.0  37.0             -12.0
#
#    Previous_Payment_Prior_sum  Statement_sum  July_Payment_Status
# 0                     10315.0        16878.0                  1.0
# 1                       181.0          177.0                  0.0
# 2                      3463.0         2919.0                  0.0
# 3                       483.0        13835.0                  0.0
# 4                      1262.0         1549.0                  0.0

# %%
# Original data
plt.figure(figsize=(7,5))
sns.heatmap(data2.corr(), annot=True, cmap='GnBu')
plt.title("Correlation Heatmap-Original data", fontsize=((16)))
plt.show()

# %%
# new data
plt.figure(figsize=(7,5))
sns.heatmap(new_data2.corr(), annot=True, cmap='GnBu')
plt.title("Correlation Heatmap-New_data", fontsize=((16)))
plt.show()

# %% [markdown]
# ### 5.4  Variables

# %%
data["Sex"].value_counts()
# Out:
# 2.0    18473
# 1.0    12097
# Name: Sex, dtype: int64

# %%
sns.countplot(data["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(data["Education"])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(data["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
data
# Out:
#        Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 0            9600.0  1.0        3.0             2.0  32.0               6.0
# 1           14400.0  2.0        3.0             2.0  30.0              -2.0
# 2            8100.0  1.0        1.0             2.0  29.0              -1.0
# 3            2700.0  2.0        2.0             1.0  31.0               0.0
# 4           14500.0  2.0        2.0             1.0  37.0              -2.0
# ...             ...  ...        ...             ...   ...               ...
# 30565        1700.0  2.0        2.0             1.0  29.0               0.0
# 30566        4700.0  1.0        1.0             2.0  33.0               2.0
# 30567        6000.0  2.0        1.0             2.0  53.0               0.0
# 30568       14500.0  2.0        3.0             2.0  46.0              -2.0
# 30569        2500.0  2.0        2.0             1.0  51.0              -1.0
#
#        Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 0                           110.0          138.0               5.0
# 1                             0.0          132.0              -2.0
# 2                           133.0            7.0              -1.0
# 3                           104.0         2891.0               0.0
# 4                           309.0          403.0              -2.0
# ...                           ...            ...               ...
# 30565                        80.0         1598.0               0.0
# 30566                        80.0         2082.0               0.0
# 30567                       191.0         5418.0               0.0
# 30568                        28.0            0.0              -2.0
# 30569                        16.0           16.0              -1.0
#
#        Previous_Payment_Prior_Feb  ...  Apr_Repay_Status  \
# 0                          2847.0  ...               7.0
# 1                             0.0  ...              -2.0
# 2                          1700.0  ...              -1.0
# 3                           140.0  ...               0.0
# 4                            94.0  ...              -2.0
# ...                           ...  ...               ...
# 30565                        80.0  ...               0.0
# 30566                        80.0  ...               0.0
# 30567                       198.0  ...               0.0
# 30568                         0.0  ...              -2.0
# 30569                        16.0  ...              -1.0
#
#        Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 0                           331.0         1080.0              12.0
# 1                             0.0            0.0              -2.0
# 2                           751.0           -4.0              -1.0
# 3                            40.0         2842.0               0.0
# 4                           362.0          381.0              -2.0
# ...                           ...            ...               ...
# 30565                        56.0         1598.0               0.0
# 30566                       100.0         2194.0               0.0
# 30567                       165.0         5740.0               0.0
# 30568                        61.0            0.0              -2.0
# 30569                        22.0           16.0              -1.0
#
#        Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 0                           535.0         1671.0               3.0
# 1                            45.0            0.0              -2.0
# 2                           498.0          747.0              -1.0
# 3                            60.0         1187.0               0.0
# 4                             0.0          362.0              -2.0
# ...                           ...            ...               ...
# 30565                        52.0         1556.0               0.0
# 30566                       100.0         2258.0               0.0
# 30567                       201.0         5842.0               0.0
# 30568                         0.0           61.0              -2.0
# 30569                        16.0           22.0              -1.0
#
#        Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 0                          4800.0         6799.0                  1.0
# 1                           136.0           45.0                  0.0
# 2                           381.0          496.0                  0.0
# 3                            19.0         1153.0                  0.0
# 4                           116.0            0.0                  0.0
# ...                           ...            ...                  ...
# 30565                        80.0         1509.0                  0.0
# 30566                       100.0         2321.0                  1.0
# 30567                       140.0         5994.0                  1.0
# 30568                         0.0            0.0                  0.0
# 30569                        16.0           16.0                  1.0
#
# [30570 rows x 24 columns]

# %%
sns.countplot(data["Marital_Status"])
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.pairplot(data=data2[['Credit_Limit','Sex',"Education",'Marital_Status','July_Payment_Status']], 
             hue = 'July_Payment_Status')

# %%
sns.pairplot(data=new_data2[['Credit_Limit','Sex',"Education",'Marital_Status','July_Payment_Status']], 
             hue = 'July_Payment_Status')

# %% [markdown]
# #### Infromation from the graph above
# ```
# We can see many fraud happen in those people who have credit limit in $10,000;
# Female easier to get fraud;
# Most of them are single;
# High education less be fraud;
#
# ```
